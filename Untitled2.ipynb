# %% [markdown]
# <a href="https://colab.research.google.com/github/fariharsyakira-source/KELOMPOK-2-TIK/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print (" hallo nama saya nanang dan saya berasal dari banjar")
# Out:
#  hallo nama saya nanang dan saya berasal dari banjar
